# %% [markdown]
# # GA Data Science (DAT10) - Lab 13
# ## Decision Trees
#
# ref: [http://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html](http://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)

# %%
import pandas as pd
import numpy as np
import pylab as pl

pd.set_option('display.max_rows',100)
pd.set_option('display.max_columns',60)

# %%
from sklearn.cross_validation import KFold

def cross_validate(X, y, classifier, k_fold) :

    # derive a set of (random) training and testing indices
    k_fold_indices = KFold(len(X), n_folds=k_fold,
                           shuffle=True, random_state=0)

    k_score_total = 0
    # for each training and testing slices run the classifier, and score the results
    for train_slice, test_slice in k_fold_indices :

        model = classifier(X[ train_slice  ],
                         y[ train_slice  ])

        k_score = model.score(X[ test_slice ],
                              y[ test_slice ])

        k_score_total += k_score

    # return the average accuracy
    return k_score_total/k_fold

# %%
# decision tree classifier (new!)
from sklearn import tree

# %% [markdown]
# ### Iris Dataset

# %% [markdown]
# Load the iris dataset:

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %% [markdown]
# Create a new pandas dataframe:

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# Create a new Decision Tree classifier using default parameters:

# %%
model = tree.DecisionTreeClassifier(random_state=0)

# %% [markdown]
# Fit the classifier with the iris data:

# %%
model.fit(df[iris.feature_names], df.species)
# Out:
# DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=None, max_features=None, min_density=None,
#             min_samples_leaf=1, min_samples_split=2, random_state=0,
#             splitter='best')

# %% [markdown]
# Let's try graphing the tree:

# %%
# from sklearn.externals.six import StringIO
with open("iris.dot", 'w') as f:
    f = tree.export_graphviz(model, out_file=f)

# %% [markdown]
# Generate a png from the .dot file (must have graphviz and pydot installed):

# %%
! dot -Tpng iris.dot -o iris.png

# %% [markdown]
# Show the image in our notebook:

# %%
from IPython.core.display import Image
Image("iris.png")

# %% [markdown]
# Now predict the classes and check the crosstabs:

# %%
# print model.predict(df[iris.feature_names])
# print df.species

# %%
pd.crosstab(df.species, model.predict(df[iris.feature_names]))
# Out:
# col_0     0   1   2
# species
# 0        50   0   0
# 1         0  50   0
# 2         0   0  50

# %% [markdown]
# Things are working, but it looks like our model is overfit, possibly due to one of these reasons:
#
#     a. The train and test datasets are the same!
#     b. We allowed a 'full' decision tree to be built.
#
# Let's run the classifier with cross-validation:

# %%
model = tree.DecisionTreeClassifier(random_state=0).fit
cross_validate(iris.data, iris.target,model,10)
# Out:
# 0.95333333333333348

# %% [markdown]
# The mean of 95% is pretty good - looks like we can train a pretty good DecisionTree classifier with this data.  Is it possible we're still overfitting due to `b`?
#
# Let's look at another Decision Tree built with just a part of the data:

# %%
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=0)
model = tree.DecisionTreeClassifier(random_state=0)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=None, max_features=None, min_density=None,
#             min_samples_leaf=1, min_samples_split=2, random_state=0,
#             splitter='best')

# %% [markdown]
# Let's predict classes for our test set using this simplified tree.

# %%
with open("iris1.dot", 'w') as f:
    f = tree.export_graphviz(model, out_file=f)
! dot -Tpng iris1.dot -o iris1.png
Image("iris1.png")

# %% [markdown]
# This tree is much simpler than the original tree based on all the data.

# %%
results = model.predict(X_test)
pd.crosstab(y_test, results)
# Out:
# col_0   0   1   2
# row_0
# 0      16   0   0
# 1       0  22   1
# 2       0   2  19

# %%
# create new dataframes with features, species, results
df_features = pd.DataFrame(X_test, columns=iris.feature_names)
df_species = pd.DataFrame(y_test, columns=['species (actual)'])
df_results = pd.DataFrame(results, columns=['species (predicted)'])

# join the features, actual, and predicted into one dataframe
df = df_features.join(df_species).join(df_results) 
df
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.8               2.8                5.1               2.4
# 1                 6.0               2.2                4.0               1.0
# 2                 5.5               4.2                1.4               0.2
# 3                 7.3               2.9                6.3               1.8
# 4                 5.0               3.4                1.5               0.2
# 5                 6.3               3.3                6.0               2.5
# 6                 5.0               3.5                1.3               0.3
# 7                 6.7               3.1                4.7               1.5
# 8                 6.8               2.8                4.8               1.4
# 9                 6.1               2.8                4.0               1.3
# 10                6.1               2.6                5.6               1.4
# 11                6.4               3.2                4.5               1.5
# 12                6.1               2.8                4.7               1.2
# 13                6.5               2.8                4.6               1.5
# 14                6.1               2.9                4.7               1.4
# 15                4.9               3.1                1.5               0.1
# 16                6.0               2.9                4.5               1.5
# 17                5.5               2.6                4.4               1.2
# 18                4.8               3.0                1.4               0.3
# 19                5.4               3.9                1.3               0.4
# 20                5.6               2.8                4.9               2.0
# 21                5.6               3.0                4.5               1.5
# 22                4.8               3.4                1.9               0.2
# 23                4.4               2.9                1.4               0.2
# 24                6.2               2.8                4.8               1.8
# 25                4.6               3.6                1.0               0.2
# 26                5.1               3.8                1.9               0.4
# 27                6.2               2.9                4.3               1.3
# 28                5.0               2.3                3.3               1.0
# 29                5.0               3.4                1.6               0.4
# 30                6.4               3.1                5.5               1.8
# 31                5.4               3.0                4.5               1.5
# 32                5.2               3.5                1.5               0.2
# 33                6.1               3.0                4.9               1.8
# 34                6.4               2.8                5.6               2.2
# 35                5.2               2.7                3.9               1.4
# 36                5.7               3.8                1.7               0.3
# 37                6.0               2.7                5.1               1.6
# 38                5.9               3.0                4.2               1.5
# 39                5.8               2.6                4.0               1.2
# 40                6.8               3.0                5.5               2.1
# 41                4.7               3.2                1.3               0.2
# 42                6.9               3.1                5.1               2.3
# 43                5.0               3.5                1.6               0.6
# 44                5.4               3.7                1.5               0.2
# 45                5.0               2.0                3.5               1.0
# 46                6.5               3.0                5.5               1.8
# 47                6.7               3.3                5.7               2.5
# 48                6.0               2.2                5.0               1.5
# 49                6.7               2.5                5.8               1.8
# 50                5.6               2.5                3.9               1.1
# 51                7.7               3.0                6.1               2.3
# 52                6.3               3.3                4.7               1.6
# 53                5.5               2.4                3.8               1.1
# 54                6.3               2.7                4.9               1.8
# 55                6.3               2.8                5.1               1.5
# 56                4.9               2.5                4.5               1.7
# 57                6.3               2.5                5.0               1.9
# 58                7.0               3.2                4.7               1.4
# 59                6.5               3.0                5.2               2.0
#
#     species (actual)  species (predicted)
# 0                  2                    2
# 1                  1                    1
# 2                  0                    0
# 3                  2                    2
# 4                  0                    0
# 5                  2                    2
# 6                  0                    0
# 7                  1                    1
# 8                  1                    1
# 9                  1                    1
# 10                 2                    2
# 11                 1                    1
# 12                 1                    1
# 13                 1                    1
# 14                 1                    1
# 15                 0                    0
# 16                 1                    1
# 17                 1                    1
# 18                 0                    0
# 19                 0                    0
# 20                 2                    2
# 21                 1                    1
# 22                 0                    0
# 23                 0                    0
# 24                 2                    2
# 25                 0                    0
# 26                 0                    0
# 27                 1                    1
# 28                 1                    1
# 29                 0                    0
# 30                 2                    2
# 31                 1                    1
# 32                 0                    0
# 33                 2                    2
# 34                 2                    2
# 35                 1                    1
# 36                 0                    0
# 37                 1                    2
# 38                 1                    1
# 39                 1                    1
# 40                 2                    2
# 41                 0                    0
# 42                 2                    2
# 43                 0                    0
# 44                 0                    0
# 45                 1                    1
# 46                 2                    2
# 47                 2                    2
# 48                 2                    1
# 49                 2                    2
# 50                 1                    1
# 51                 2                    2
# 52                 1                    1
# 53                 1                    1
# 54                 2                    2
# 55                 2                    2
# 56                 2                    1
# 57                 2                    2
# 58                 1                    1
# 59                 2                    2

# %%
# extract the records where the predictions were incorrect
df_errors = df[(df['species (actual)'] != df['species (predicted)'])]
df_errors
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 37                6.0               2.7                5.1               1.6
# 48                6.0               2.2                5.0               1.5
# 56                4.9               2.5                4.5               1.7
#
#     species (actual)  species (predicted)
# 37                 1                    2
# 48                 2                    1
# 56                 2                    1

# %% [markdown]
# Trace the tree from root to leaf based to see where the rule was insufficient to correctly categorize #37, #48, and #56.

# %% [markdown]
# What does cross-validation look like if we use only our Train set?

# %%
model = tree.DecisionTreeClassifier(random_state=0).fit
cross_validate(X_train, y_train,model,10)
# Out:
# 0.96666666666666656

# %% [markdown]
# Turns out the average score is actually slightly better, even though we used less data.  Maybe training with the entire dataset caused the model to be too complex - i.e. overfit?
#
# *Note: It is always good to double-check such cases, try with different random seeds, etc.  One instance often does not tell the whole story.*

# %% [markdown]
# #### Limiting Tree Depth
#
# Looking at this second model, we can see that most of the work is done in the first 3 branches - only 3 items in the training set were categorized by the 4th branch.   What happens if we limit the depth of the tree to just 3 levels?

# %%
model = tree.DecisionTreeClassifier(max_depth=3, random_state=0)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(compute_importances=None, criterion='gini',
#             max_depth=3, max_features=None, max_leaf_nodes=None,
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             random_state=0, splitter='best')

# %%
with open("iris2.dot", 'w') as f:
    f = tree.export_graphviz(model, out_file=f)
! dot -Tpng iris2.dot -o iris2.png
Image("iris2.png")

# %% [markdown]
# Which features are most important in this classifier?  We can check by looking at the `importances`:

# %% [markdown]
# model.feature_importances_
# Does limiting the max depth affect our average model performance with this training data?

# %%
model = tree.DecisionTreeClassifier(max_depth=3, random_state=0).fit
cross_validate(iris.data, iris.target,model,10)
# Out:
# 0.94000000000000006

# %% [markdown]
# ### Random Forest Classification

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=1).fit
cross_validate(iris.data, iris.target, model, 10)
# Out:
# 0.95333333333333337

# %% [markdown]
# ### Heart Disease Dataset
# ref: [https://archive.ics.uci.edu/ml/datasets/Heart+Disease](https://archive.ics.uci.edu/ml/datasets/Heart+Disease)

# %% [markdown]
# #### Features
#
#     Dataset has 76 total attributes - 14 attributes are used:
#     1. #3 (age)
#     2. #4 (sex)
#     3. #9 (cp)
#     4. #10 (trestbps)
#     5. #12 (chol)
#     6. #16 (fbs)
#     7. #19 (restecg)
#     8. #32 (thalach)
#     9. #38 (exang)
#     10. #40 (oldpeak)
#     11. #41 (slope)
#     12. #44 (ca)
#     13. #51 (thal)
#     14. #58 (num) (the predicted attribute - 0 is healthy and 1,2,3,4 indicate heart disease)

# %% [markdown]
# ### Class Exercise: Implement Random Forest

# %% [markdown]
# #### Import the dataset into a pandas dataframe:
#
# Note: You'll have to manually add column labels

# %%
data = pd.read_csv("heart_disease.csv",
                   header=False)
data.columns=['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num']
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   67    1   4       160   286    0        2      108      1      1.5      2
# 1   67    1   4       120   229    0        2      129      1      2.6      2
# 2   37    1   3       130   250    0        0      187      0      3.5      3
# 3   41    0   2       130   204    0        2      172      0      1.4      1
# 4   56    1   2       120   236    0        0      178      0      0.8      1
#
#     ca thal  num
# 0  3.0  3.0    2
# 1  2.0  7.0    1
# 2  0.0  3.0    0
# 3  0.0  3.0    0
# 4  0.0  3.0    0

# %% [markdown]
# #### Prepare and validate the data:

# %% [markdown]
# Investigate the data and check for missing values - we've used .info() before:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 302 entries, 0 to 301
# Data columns (total 14 columns):
# age         302 non-null float64
# sex         302 non-null float64
# cp          302 non-null float64
# trestbps    302 non-null float64
# chol        302 non-null float64
# fbs         302 non-null float64
# restecg     302 non-null float64
# thalach     302 non-null float64
# exang       302 non-null float64
# oldpeak     302 non-null float64
# slope       302 non-null float64
# ca          302 non-null object
# thal        302 non-null object
# num         302 non-null int64
# dtypes: float64(11), int64(1), object(2)

# %%
data.replace(to_replace = '?', value = np.NaN, inplace=True)
data[data['thal'].isnull() | data['ca'].isnull()]
# data = data.convert_objects(convert_numeric = True)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 86    53    0   3       128   216    0        2      115      0      0.0
# 165   52    1   3       138   223    0        0      169      0      0.0
# 191   43    1   4       132   247    1        2      143      1      0.1
# 265   52    1   4       128   204    1        0      156      1      1.0
# 286   58    1   2       125   220    0        0      144      0      0.4
# 301   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca thal  num
# 86       1  0.0  NaN    0
# 165      1  NaN  3.0    0
# 191      2  NaN  7.0    1
# 265      2  0.0  NaN    2
# 286      2  NaN  7.0    0
# 301      1  NaN  3.0    0

# %% [markdown]
# #### Clean the data to ensure it can be used in a random forest algorithm

# %%
data.dropna(inplace = True)
len(data)
# Out:
# 296

# %% [markdown]
# #### Select Features and convert Target to Boolean Class for Heart Disease (i.e., values 1, 2, 3 and 4 all indicate heart disease)

# %%
data['num'].replace(to_replace = [1,2,3,4], value = 1, inplace=True)
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   67    1   4       160   286    0        2      108      1      1.5      2
# 1   67    1   4       120   229    0        2      129      1      2.6      2
# 2   37    1   3       130   250    0        0      187      0      3.5      3
# 3   41    0   2       130   204    0        2      172      0      1.4      1
# 4   56    1   2       120   236    0        0      178      0      0.8      1
#
#     ca thal  num
# 0  3.0  3.0    1
# 1  2.0  7.0    1
# 2  0.0  3.0    0
# 3  0.0  3.0    0
# 4  0.0  3.0    0

# %% [markdown]
# #### Build the model and score with cross-validation

# %%
data_feat = data[['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']]

# %%
data_tar = data['num']

# %%
len(data_tar) == len(data_feat)
# Out:
# True

# %%
model = RandomForestClassifier(random_state=0).fit
model
# Out:
# <bound method RandomForestClassifier.fit of RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=0,
#             verbose=0)>

# %%
cross_validate(data_feat.values, data_tar.values, model, 10)
# Out:
# 0.82747126436781604

# %% [markdown]
# #### How important are the various features?

# %%
feat_imp = RandomForestClassifier(random_state=0).fit(data_feat.values, data_tar.values).feature_importances_

# %%
feats = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']
for i in zip(feats, feat_imp):
    print '{0} attribute had importance {1}'.format(i[0], i[1])
# Out:
# age had importance 0.113474376945
# sex had importance 0.0187183131965
# cp had importance 0.14025560943
# trestbps had importance 0.087189048712
# chol had importance 0.0669441730934
# fbs had importance 0.00951070558203
# restecg had importance 0.0178747719297
# thalach had importance 0.158767104025
# exang had importance 0.028886167705
# oldpeak had importance 0.0988915054894
# slope had importance 0.0286162319358
# ca had importance 0.112129420194
# thal had importance 0.118742571762

# %%
ForestClassifier()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-e4a940c66fbe> in <module>()
# ----> 1 ForestClassifier()
#
# NameError: name 'ForestClassifier' is not defined
